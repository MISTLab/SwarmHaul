# %%
# Import the necessary Python libraries
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from math import log10
import math
from scipy.spatial.distance import pdist, squareform
from matplotlib.patches import Patch
import matplotlib.lines as mlines
from matplotlib import colors as mcolors
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.cbook import get_sample_data
import os.path
import csv
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
DATA_DIR = "/collobrative_transport/data"

# %%
ROBOTS = [25,50,100]
PATH_TAKEN = ['straight', 'zigzac', 'straight_rot']
INTER_CAGE_DIST =0.45 # 0.65, 0.85
MASS = 5
OBJECT_SHAPE = [0,1,2]
REP=30
TARGET_x=[-10,-10]
TARGET_y=[-0,-2]
TARGET_TOLERENCE = 0.1

# %%
print("EXPERIMENTAL DATA FILES STATS")
for robot in ROBOTS:
    for path in PATH_TAKEN:
        
        object_shape = 0
        if(robot == 50):
            object_shape = 1
        elif(robot == 100):
            object_shape = 2
        for movement in [0]:
            for rep in range(1,REP+1):
                if (not os.path.exists(DATA_DIR+"/pos_"+str(robot)+'_'+path+'_'
                                      +str(INTER_CAGE_DIST)+'_'+str(MASS)+'_'
                                      +str(object_shape)+'_'+str(rep)
                                      +'.csv')) or (not os.path.exists(DATA_DIR
                                      +"/perf_"+str(robot)+'_'+path+'_'+str(INTER_CAGE_DIST)+'_'
                                      +str(MASS)+'_'+str(object_shape)+'_'+str(rep)
                                      +'.csv')) or (not os.path.exists(DATA_DIR
                                      +"/effec_"+str(robot)+'_'+path+'_'+str(INTER_CAGE_DIST)+'_'
                                      +str(MASS)+'_'+str(object_shape)+'_'+str(rep)+'.csv')):
                    print("EXP: ROBOT {} PATH {} REP {} does not exist".format(robot,path,rep))
                    print(DATA_DIR+"/pos_"+str(robot)+'_'+path+'_'+str(INTER_CAGE_DIST)+'_'+str(MASS)+'_'+str(object_shape)+'_'+str(rep)+'.csv')
# Out:
# EXPERIMENTAL DATA FILES STATS
# EXP: ROBOT 25 PATH zigzac REP 22 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_22.csv
# EXP: ROBOT 25 PATH zigzac REP 23 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_23.csv
# EXP: ROBOT 25 PATH zigzac REP 24 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_24.csv
# EXP: ROBOT 25 PATH zigzac REP 25 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_25.csv
# EXP: ROBOT 25 PATH zigzac REP 26 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_26.csv
# EXP: ROBOT 25 PATH zigzac REP 27 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_27.csv
# EXP: ROBOT 25 PATH zigzac REP 28 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_28.csv
# EXP: ROBOT 25 PATH zigzac REP 29 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_29.csv
# EXP: ROBOT 25 PATH zigzac REP 30 does not exist
# /collobrative_transport/data/pos_25_zigzac_0.45_5_0_30.csv
# EXP: ROBOT 25 PATH straight_rot REP 22 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_22.csv
# EXP: ROBOT 25 PATH straight_rot REP 23 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_23.csv
# EXP: ROBOT 25 PATH straight_rot REP 24 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_24.csv
# EXP: ROBOT 25 PATH straight_rot REP 25 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_25.csv
# EXP: ROBOT 25 PATH straight_rot REP 26 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_26.csv
# EXP: ROBOT 25 PATH straight_rot REP 27 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_27.csv
# EXP: ROBOT 25 PATH straight_rot REP 28 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_28.csv
# EXP: ROBOT 25 PATH straight_rot REP 29 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_29.csv
# EXP: ROBOT 25 PATH straight_rot REP 30 does not exist
# /collobrative_transport/data/pos_25_straight_rot_0.45_5_0_30.csv
# EXP: ROBOT 50 PATH straight REP 7 does not exist
# /collobrative_transport/data/pos_50_straight_0.45_5_1_7.csv
# EXP: ROBOT 50 PATH straight REP 16 does not exist
# /collobrative_transport/data/pos_50_straight_0.45_5_1_16.csv
# EXP: ROBOT 50 PATH straight REP 18 does not exist
# /collobrative_transport/data/pos_50_straight_0.45_5_1_18.csv
# EXP: ROBOT 50 PATH straight REP 26 does not exist
# /collobrative_transport/data/pos_50_straight_0.45_5_1_26.csv
# EXP: ROBOT 50 PATH zigzac REP 7 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_7.csv
# EXP: ROBOT 50 PATH zigzac REP 16 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_16.csv
# EXP: ROBOT 50 PATH zigzac REP 18 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_18.csv
# EXP: ROBOT 50 PATH zigzac REP 22 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_22.csv
# EXP: ROBOT 50 PATH zigzac REP 23 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_23.csv
# EXP: ROBOT 50 PATH zigzac REP 24 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_24.csv
# EXP: ROBOT 50 PATH zigzac REP 25 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_25.csv
# EXP: ROBOT 50 PATH zigzac REP 26 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_26.csv
# EXP: ROBOT 50 PATH zigzac REP 27 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_27.csv
# EXP: ROBOT 50 PATH zigzac REP 28 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_28.csv
# EXP: ROBOT 50 PATH zigzac REP 29 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_29.csv
# EXP: ROBOT 50 PATH zigzac REP 30 does not exist
# /collobrative_transport/data/pos_50_zigzac_0.45_5_1_30.csv
# EXP: ROBOT 50 PATH straight_rot REP 1 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_1.csv
# EXP: ROBOT 50 PATH straight_rot REP 2 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_2.csv
# EXP: ROBOT 50 PATH straight_rot REP 3 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_3.csv
# EXP: ROBOT 50 PATH straight_rot REP 4 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_4.csv
# EXP: ROBOT 50 PATH straight_rot REP 5 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_5.csv
# EXP: ROBOT 50 PATH straight_rot REP 6 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_6.csv
# EXP: ROBOT 50 PATH straight_rot REP 7 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_7.csv
# EXP: ROBOT 50 PATH straight_rot REP 8 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_8.csv
# EXP: ROBOT 50 PATH straight_rot REP 9 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_9.csv
# EXP: ROBOT 50 PATH straight_rot REP 10 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_10.csv
# EXP: ROBOT 50 PATH straight_rot REP 11 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_11.csv
# EXP: ROBOT 50 PATH straight_rot REP 12 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_12.csv
# EXP: ROBOT 50 PATH straight_rot REP 13 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_13.csv
# EXP: ROBOT 50 PATH straight_rot REP 14 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_14.csv
# EXP: ROBOT 50 PATH straight_rot REP 15 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_15.csv
# EXP: ROBOT 50 PATH straight_rot REP 16 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_16.csv
# EXP: ROBOT 50 PATH straight_rot REP 17 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_17.csv
# EXP: ROBOT 50 PATH straight_rot REP 18 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_18.csv
# EXP: ROBOT 50 PATH straight_rot REP 19 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_19.csv
# EXP: ROBOT 50 PATH straight_rot REP 20 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_20.csv
# EXP: ROBOT 50 PATH straight_rot REP 21 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_21.csv
# EXP: ROBOT 50 PATH straight_rot REP 22 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_22.csv
# EXP: ROBOT 50 PATH straight_rot REP 23 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_23.csv
# EXP: ROBOT 50 PATH straight_rot REP 24 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_24.csv
# EXP: ROBOT 50 PATH straight_rot REP 25 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_25.csv
# EXP: ROBOT 50 PATH straight_rot REP 26 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_26.csv
# EXP: ROBOT 50 PATH straight_rot REP 27 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_27.csv
# EXP: ROBOT 50 PATH straight_rot REP 28 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_28.csv
# EXP: ROBOT 50 PATH straight_rot REP 29 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_29.csv
# EXP: ROBOT 50 PATH straight_rot REP 30 does not exist
# /collobrative_transport/data/pos_50_straight_rot_0.45_5_1_30.csv
# EXP: ROBOT 100 PATH straight REP 5 does not exist
# /collobrative_transport/data/pos_100_straight_0.45_5_2_5.csv
# EXP: ROBOT 100 PATH straight REP 13 does not exist
# /collobrative_transport/data/pos_100_straight_0.45_5_2_13.csv
# EXP: ROBOT 100 PATH straight REP 29 does not exist
# /collobrative_transport/data/pos_100_straight_0.45_5_2_29.csv
# EXP: ROBOT 100 PATH zigzac REP 5 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_5.csv
# EXP: ROBOT 100 PATH zigzac REP 13 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_13.csv
# EXP: ROBOT 100 PATH zigzac REP 22 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_22.csv
# EXP: ROBOT 100 PATH zigzac REP 23 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_23.csv
# EXP: ROBOT 100 PATH zigzac REP 24 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_24.csv
# EXP: ROBOT 100 PATH zigzac REP 25 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_25.csv
# EXP: ROBOT 100 PATH zigzac REP 26 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_26.csv
# EXP: ROBOT 100 PATH zigzac REP 27 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_27.csv
# EXP: ROBOT 100 PATH zigzac REP 28 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_28.csv
# EXP: ROBOT 100 PATH zigzac REP 29 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_29.csv
# EXP: ROBOT 100 PATH zigzac REP 30 does not exist
# /collobrative_transport/data/pos_100_zigzac_0.45_5_2_30.csv
# EXP: ROBOT 100 PATH straight_rot REP 1 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_1.csv
# EXP: ROBOT 100 PATH straight_rot REP 2 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_2.csv
# EXP: ROBOT 100 PATH straight_rot REP 3 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_3.csv
# EXP: ROBOT 100 PATH straight_rot REP 5 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_5.csv
# EXP: ROBOT 100 PATH straight_rot REP 6 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_6.csv
# EXP: ROBOT 100 PATH straight_rot REP 8 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_8.csv
# EXP: ROBOT 100 PATH straight_rot REP 9 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_9.csv
# EXP: ROBOT 100 PATH straight_rot REP 11 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_11.csv
# EXP: ROBOT 100 PATH straight_rot REP 12 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_12.csv
# EXP: ROBOT 100 PATH straight_rot REP 13 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_13.csv
# EXP: ROBOT 100 PATH straight_rot REP 14 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_14.csv
# EXP: ROBOT 100 PATH straight_rot REP 15 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_15.csv
# EXP: ROBOT 100 PATH straight_rot REP 17 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_17.csv
# EXP: ROBOT 100 PATH straight_rot REP 18 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_18.csv
# EXP: ROBOT 100 PATH straight_rot REP 20 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_20.csv
# EXP: ROBOT 100 PATH straight_rot REP 21 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_21.csv
# EXP: ROBOT 100 PATH straight_rot REP 22 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_22.csv
# EXP: ROBOT 100 PATH straight_rot REP 23 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_23.csv
# EXP: ROBOT 100 PATH straight_rot REP 24 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_24.csv
# EXP: ROBOT 100 PATH straight_rot REP 25 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_25.csv
# EXP: ROBOT 100 PATH straight_rot REP 26 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_26.csv
# EXP: ROBOT 100 PATH straight_rot REP 27 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_27.csv
# EXP: ROBOT 100 PATH straight_rot REP 28 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_28.csv
# EXP: ROBOT 100 PATH straight_rot REP 29 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_29.csv
# EXP: ROBOT 100 PATH straight_rot REP 30 does not exist
# /collobrative_transport/data/pos_100_straight_rot_0.45_5_2_30.csv

# %%
def get_names_for_posfile(robot):
    name = ['time']
    for i in range(0,robot):
        name.append('id:'+str(i))
        name.append('x_'+str(i))
        name.append('y_'+str(i))
        name.append('z_'+str(i))
    name.append('obj_x')
    name.append('obj_y')
    name.append('obj_yaw')
    return name
def get_names_for_effecfile(robot):
    name = ['time']
    for i in range(0,robot):
        name.append('id:'+str(i))
        name.append('ep_'+str(i))
        name.append('er_'+str(i))
        name.append('task_'+str(i))
        name.append('c_size_'+str(i))
        name.append('p_size_'+str(i))
        name.append('r_size_'+str(i))
        name.append('t_size_'+str(i))
    return name

# %%
# Reads the data of a single experiment
def read_pos_datafile(name, robot):
    fname = DATA_DIR + "/pos_" + name
    print('Reading: '+fname+'.csv')
    names = get_names_for_posfile(robot)
    return pd.read_csv(fname+'.csv', names=names, header=None, skiprows=1, engine='python')

# %%
# Reads the data of a single experiment
def read_effec_datafile(name, robot):
    fname = DATA_DIR + "/effec_" + name
    print('Reading: '+fname+'.csv')
    names = get_names_for_effecfile(robot)
    return pd.read_csv(fname+'.csv', names=names, header=None, skiprows=1, engine='python')

# %%
def dist(row,x1,y1):
    return math.hypot((row['obj_x']-x1),(row['obj_y']-y1))

# %%
def get_time_for_obj_at_tar(c_df, setting):
    if(setting <=1):
        c_df[['obj_dis']] = c_df.apply(dist,x1=TARGET_x[0],y1=TARGET_y[0],axis = 1).apply(pd.Series)
    else:
        c_df[['obj_dis']] = c_df.apply(dist,x1=TARGET_x[1],y1=TARGET_y[1],axis = 1).apply(pd.Series)
    
    c_df[c_df['obj_dis']<= TARGET_TOLERENCE].index.tolist()

# %%
pos_df = read_pos_datafile('25_zigzac_0.45_5_0_21',25)
# Out:
# Reading: /collobrative_transport/data/pos_25_zigzac_0.45_5_0_21.csv

# %%
pos_df
# Out:
#       time  id:0      x_0      y_0  z_0  id:1      x_1      y_1  z_1  id:2  \
# 0        1     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 1        2     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 2        3     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 3        4     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 4        5     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 5        6     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 6        7     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 7        8     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 8        9     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 9       10     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 10      11     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 11      12     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 12      13     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 13      14     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 14      15     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 15      16     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 16      17     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 17      18     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 18      19     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 19      20     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 20      21     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 21      22     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 22      23     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 23      24     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 24      25     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 25      26     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 26      27     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 27      28     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 28      29     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# 29      30     0 -4.29881 -5.64028    0     1 -5.42619 -5.10192    0     2
# ...    ...   ...      ...      ...  ...   ...      ...      ...  ...   ...
# 5267  5268     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5268  5269     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5269  5270     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5270  5271     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5271  5272     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5272  5273     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5273  5274     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5274  5275     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5275  5276     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5276  5277     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5277  5278     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5278  5279     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5279  5280     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5280  5281     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5281  5282     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5282  5283     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5283  5284     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5284  5285     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5285  5286     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5286  5287     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5287  5288     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5288  5289     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5289  5290     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5290  5291     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5291  5292     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5292  5293     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5293  5294     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5294  5295     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5295  5296     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
# 5296  5297     0 -9.14759 -3.09200    0     1 -8.95440 -2.37055    0     2
#
#         ...        x_23      y_23  z_23  id:24     x_24     y_24  z_24  \
# 0       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 1       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 2       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 3       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 4       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 5       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 6       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 7       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 8       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 9       ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 10      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 11      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 12      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 13      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 14      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 15      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 16      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 17      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 18      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 19      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 20      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 21      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 22      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 23      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 24      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 25      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 26      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 27      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 28      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# 29      ...    -5.47856 -4.503330     0     24 -4.02272 -5.31897     0
# ...     ...         ...       ...   ...    ...      ...      ...   ...
# 5267    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5268    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5269    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5270    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5271    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5272    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5273    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5274    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5275    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5276    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5277    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5278    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5279    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5280    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5281    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5282    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5283    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5284    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5285    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5286    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5287    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5288    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5289    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5290    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5291    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5292    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5293    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5294    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5295    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
# 5296    ...    -9.80350 -0.896994     0     24 -9.61227 -3.06833     0
#
#         obj_x    obj_y   obj_yaw
# 0      0.0000  0.00000  0.000000
# 1      0.0000  0.00000  0.000000
# 2      0.0000  0.00000  0.000000
# 3      0.0000  0.00000  0.000000
# 4      0.0000  0.00000  0.000000
# 5      0.0000  0.00000  0.000000
# 6      0.0000  0.00000  0.000000
# 7      0.0000  0.00000  0.000000
# 8      0.0000  0.00000  0.000000
# 9      0.0000  0.00000  0.000000
# 10     0.0000  0.00000  0.000000
# 11     0.0000  0.00000  0.000000
# 12     0.0000  0.00000  0.000000
# 13     0.0000  0.00000  0.000000
# 14     0.0000  0.00000  0.000000
# 15     0.0000  0.00000  0.000000
# 16     0.0000  0.00000  0.000000
# 17     0.0000  0.00000  0.000000
# 18     0.0000  0.00000  0.000000
# 19     0.0000  0.00000  0.000000
# 20     0.0000  0.00000  0.000000
# 21     0.0000  0.00000  0.000000
# 22     0.0000  0.00000  0.000000
# 23     0.0000  0.00000  0.000000
# 24     0.0000  0.00000  0.000000
# 25     0.0000  0.00000  0.000000
# 26     0.0000  0.00000  0.000000
# 27     0.0000  0.00000  0.000000
# 28     0.0000  0.00000  0.000000
# 29     0.0000  0.00000  0.000000
# ...       ...      ...       ...
# 5267 -10.0046 -1.97541 -0.053502
# 5268 -10.0046 -1.97541 -0.053502
# 5269 -10.0046 -1.97541 -0.053502
# 5270 -10.0046 -1.97541 -0.053502
# 5271 -10.0046 -1.97541 -0.053502
# 5272 -10.0046 -1.97541 -0.053502
# 5273 -10.0046 -1.97541 -0.053502
# 5274 -10.0046 -1.97541 -0.053502
# 5275 -10.0046 -1.97541 -0.053502
# 5276 -10.0046 -1.97541 -0.053502
# 5277 -10.0046 -1.97541 -0.053502
# 5278 -10.0046 -1.97541 -0.053502
# 5279 -10.0046 -1.97541 -0.053502
# 5280 -10.0046 -1.97541 -0.053502
# 5281 -10.0046 -1.97541 -0.053502
# 5282 -10.0046 -1.97541 -0.053502
# 5283 -10.0046 -1.97541 -0.053502
# 5284 -10.0046 -1.97541 -0.053502
# 5285 -10.0046 -1.97541 -0.053502
# 5286 -10.0046 -1.97541 -0.053502
# 5287 -10.0046 -1.97541 -0.053502
# 5288 -10.0046 -1.97541 -0.053502
# 5289 -10.0046 -1.97541 -0.053502
# 5290 -10.0046 -1.97541 -0.053502
# 5291 -10.0046 -1.97541 -0.053502
# 5292 -10.0046 -1.97541 -0.053502
# 5293 -10.0046 -1.97541 -0.053502
# 5294 -10.0046 -1.97541 -0.053502
# 5295 -10.0046 -1.97541 -0.053502
# 5296 -10.0046 -1.97541 -0.053502
#
# [5297 rows x 104 columns]
